# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import os
import pymongo
import datetime
from functools import reduce
import csv
import pandas as pd

# %%
myclient = pymongo.MongoClient('mongodb://modelmarket:Qw123456789@naibo.wang:8088/', connect=False)
mydb = myclient['exps']
results = mydb["results"]
exp_results = list(results.find())  # lte 小于等于

# %%
def get_dir_size(dir):
    size = 0
    for root, dirs, files in os.walk(dir):
        size += sum([os.path.getsize(os.path.join(root, name)) for name in files])
    return round(size/1024/1024,1)

# %%
for result in exp_results:
#     print("Model Name:", result["model_name"])
    path = result["model_storage_path"] + "/fine-tune"
#     print("Model Size:",get_dir_size(path),"MB")
    time_dict = reduce(lambda pre, cur: cur if cur['name'] == result["model_storage_path"]+"/fine-tune_model_evaluate_training" else pre, result["time_records"], None)
    test_time = time_dict["end"] - time_dict["start"]
#     print("Test time:",test_time.total_seconds(),"s")
    time_dict = reduce(lambda pre, cur: cur if cur['name'] == "transfer_learning_fit" else pre, result["time_records"], None)
    transfer_learning_time = time_dict["end"] - time_dict["start"]
#     print("transfer learning training time:",transfer_learning_time.total_seconds()//60,"min")
    time_dict = reduce(lambda pre, cur: cur if cur['name'] == "fine_tune_fit" else pre, result["time_records"], None)
    fine_tune_time = time_dict["end"] - time_dict["start"]
#     print("fine tune training time:",fine_tune_time.total_seconds()//60,"min")
    training_log = path + "/training_log.csv"
    plot_list = []
    with open(training_log,'r') as f:
        reader = csv.reader(f)
        i = 0
        for row in reader:
            plot_list.append(row)
    plot_list = plot_list[1:]
    loss_train = []
    loss_val = []
    acc_train = []
    acc_val = []
    for item in plot_list:
        acc_train.append(float(item[1]))
        loss_train.append(float(item[2]))
        acc_val.append(float(item[3]))
        loss_val.append(float(item[4]))
#     print(plot_list)
    epochs = range(1,31)
#     fig = plt.figure()
#     f, plots = plt.subplots(1, 2, figsize=(20, 20))
#     plots[0].plot(epochs, acc_train, 'g', label='Training accuracy')
#     plots[0].plot(epochs, acc_val, 'b', label='validation accuracy')
#     plots[0].set_title('Training and Validation accuracy')
#     plots[0].set_xlabel('Epochs')
#     plots[0].set_ylabel('Accuracy')
#     plots[0].legend()
#     plots[1].plot(epochs, loss_train, 'g', label='Training Loss')
#     plots[1].plot(epochs, loss_val, 'b', label='validation Loss')
#     plots[1].set_title('Training and Validation Loss')
#     plots[1].set_xlabel('Epochs')
#     plots[1].set_ylabel('Loss')
#     plots[1].legend()
#     f.suptitle(result["model_name"], fontsize=16)
    print(acc_train)
    plt.figure( figsize=(15, 10))
    plt.plot(epochs, acc_train, 'g', label='Training accuracy')
    plt.plot(epochs, acc_val, 'b', label='validation accuracy')
    plt.title('Training and Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig("figs/"+result["model_name"]+".png")
    plt.show()
# Out:
# [0.437624990940094, 0.6548500061035156, 0.7530750036239624, 0.8111500144004822, 0.8503999710083008, 0.8782250285148621, 0.9045000076293945, 0.9217749834060669, 0.9362000226974487, 0.9523000121116638, 0.9604250192642212, 0.9661250114440918, 0.9708750247955322, 0.9738500118255615, 0.9751999974250793, 0.9764999747276306, 0.9796000123023987, 0.9834750294685364, 0.9841750264167786, 0.9810500144958496, 0.9840250015258789, 0.9854999780654907, 0.9880750179290771, 0.9865000247955322, 0.9884250164031982, 0.9895750284194946, 0.9897249937057495, 0.9908499717712402, 0.9922749996185303, 0.989425003528595]
# ...

# %%
# format_results = []
# with open("result_format.csv",'r') as f:
#     reader = csv.reader(f)
#     i = 0
#     for row in reader:
#         format_results.append(row)
# format_results = format_results[1:]

def get_rank_results(field="testSet_after_fine_tune"):
    data_frame = pd.read_csv("result_format.csv")
    rank_test_fine_tune = data_frame.sort_values(field, ascending=False)
    best_results = list(rank_test_fine_tune["rank"].values)
    TOP1 = [best_results[0]]
    TOP3 = best_results[:3]
    TOP5 = best_results[:5]
    TOP10 = best_results[:10]
    TOP15 = best_results[:15]
    TOP20 = best_results[:20]
    rank_results = [TOP1, TOP3, TOP5, TOP10, TOP15, TOP20]
    return rank_results

# print(get_rank_results())

def compare_results(field = "validationSet_after_fine_tune"):
    rank_results_label = get_rank_results()
    rank_results_field = get_rank_results(field)
    print("Comparision results for", field)
    TOP1 = list(set(rank_results_field[0]) & set(rank_results_label[0]))
    print("TOP1:", len(TOP1),"/ 1")
    TOP3 = list(set(rank_results_field[1]) & set(rank_results_label[1]))
    print("TOP3:", len(TOP3),"/ 3")
    TOP5 = list(set(rank_results_field[2]) & set(rank_results_label[2]))
    print("TOP5:", len(TOP5),"/ 5")
    TOP10 = list(set(rank_results_field[3]) & set(rank_results_label[3]))
    print("TOP10:", len(TOP10),"/ 10")
    TOP15 = list(set(rank_results_field[4]) & set(rank_results_label[4]))
    print("TOP15:", len(TOP15),"/ 15")
    TOP20 = list(set(rank_results_field[5]) & set(rank_results_label[5]))
    print("TOP20:", len(TOP20),"/ 20")
#     print(TOP3)
#     print(TOP5)
#     print(TOP10)
#     print(TOP15)
#     print(TOP20)

# %%
compare_results("validationSet_after_fine_tune")
compare_results("validationSet_after_transfer_learning")
compare_results("trainingSet_after_fine_tune")
compare_results("trainingSet_after_transfer_learning")
# Out:
# Comparision results for validationSet_after_fine_tune
# TOP1: 1 / 1
# TOP3: 3 / 3
# TOP5: 4 / 5
# TOP10: 10 / 10
# TOP15: 13 / 15
# TOP20: 19 / 20
# Comparision results for validationSet_after_transfer_learning
# TOP1: 1 / 1
# TOP3: 1 / 3
# TOP5: 1 / 5
# TOP10: 4 / 10
# TOP15: 9 / 15
# TOP20: 13 / 20
# Comparision results for trainingSet_after_fine_tune
# TOP1: 1 / 1
# TOP3: 1 / 3
# TOP5: 2 / 5
# TOP10: 2 / 10
# TOP15: 4 / 15
# TOP20: 5 / 20
# Comparision results for trainingSet_after_transfer_learning
# TOP1: 0 / 1
# TOP3: 0 / 3
# TOP5: 1 / 5
# TOP10: 1 / 10
# TOP15: 2 / 15
# TOP20: 5 / 20

# %%
data_frame = pd.read_csv("result_format.csv")
rank_test_fine_tune = data_frame.sort_values("testSet_after_fine_tune", ascending=False)

# %%
rank = []
for i in range(len(rank_test_fine_tune)):
    rank.append(i+1)
rank_test_fine_tune["rank"] = rank
rank_test_fine_tune
# Out:
#                                      model_name original_dataset   dataset  \
# 56                      convnext_xlarge_21k_224     ImageNet-21k  cifar100
# 64                   convnext_large_1k_224_fe_1  ILSVRC-2012-CLS  cifar100
# 47                     imagenet_efficientnet_v2  ILSVRC-2012-CLS  cifar100
# 54                    convnext_tiny_1k_224_fe_1  ILSVRC-2012-CLS  cifar100
# 48  imagenet_efficientnet_v2_imagenet21k_ft1k_l     ImageNet-21k  cifar100
# ..                                          ...              ...       ...
# 63                               bit_m-r101x1_1     ImageNet-21k  cifar100
# 50                imagenet_mobilenet_v1_025_128  ILSVRC-2012-CLS  cifar100
# 34                                bit_m-r50x1_1     ImageNet-21k  cifar100
# 26                               bit_m-r101x1_1     ImageNet-21k  cifar100
# 60                   deit_tiny_patch16_224_fe_1  ILSVRC-2012-CLS  cifar100
#
# ...
